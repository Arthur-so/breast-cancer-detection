# %%
import cv2
import os

def processar_imagens(pasta_imagens):
    # Criar a pasta de saída 'roi' dentro da pasta de imagens
    pasta_saida = os.path.join(pasta_imagens, 'roi')
    if not os.path.exists(pasta_saida):
        os.makedirs(pasta_saida)

    # Processar cada imagem na pasta
    for nome_arquivo in os.listdir(pasta_imagens):
        caminho_imagem = os.path.join(pasta_imagens, nome_arquivo)

        # Verificar se o arquivo é uma imagem (pode-se adicionar outras extensões se necessário)
        if nome_arquivo.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp')):
            # Carregar a imagem em escala de cinza
            imagem = cv2.imread(caminho_imagem, cv2.IMREAD_GRAYSCALE)
            
            # Verificar se a imagem foi carregada corretamente
            if imagem is None:
                print(f"Erro ao carregar a imagem: {caminho_imagem}")
                continue
            
            # Definir as coordenadas do retângulo para a região da axila para baixo
            altura, largura = imagem.shape
            x_inicial = 0
            y_inicial = int(altura // 2.5)  # Aproximadamente 1/3 da altura
            x_final = largura
            y_final = altura - (altura // 15)

            # Extrair a região de interesse (ROI)
            roi = imagem[y_inicial:y_final, x_inicial:x_final]

            # Salvar a imagem do ROI na pasta de saída
            caminho_saida = os.path.join(pasta_saida, f'roi_{nome_arquivo}')
            cv2.imwrite(caminho_saida, roi)
            print(f"ROI salvo em: {caminho_saida}")

# Exemplo de uso:
pasta_imagens = 'D:/Unifesp/IA/termografia/termography/dataset/sick/'  # Substitua pelo caminho da pasta contendo as imagens
processar_imagens(pasta_imagens)
# Out:
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_100_sick_425_58.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_10_sick_209_57.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_11_sick_210_55.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_12_sick_213_82.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_13_sick_240_63.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_14_sick_241_53.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_15_sick_242_87.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_16_sick_245_62.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_17_sick_246_74.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_18_sick_255_86.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_19_sick_256_83.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_1_sick_138_77.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_20_sick_257_59.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_21_sick_258_66.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_22_sick_259_65.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_23_sick_260_77.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_24_sick_261_67.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_25_sick_263_62.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_26_sick_264_65.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_27_sick_266_69.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_28_sick_267_49.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_29_sick_268_61.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_2_sick_179_91.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_30_sick_269_42.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_31_sick_270_75.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_32_sick_271_59.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_33_sick_273_60.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_34_sick_274_37.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_35_sick_277_46.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_36_sick_278_59.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_37_sick_281_43.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_38_sick_282_46.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_39_sick_283_50.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_3_sick_180_48.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_40_sick_285_57.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_41_sick_286_50.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_42_sick_287_62.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_43_sick_312_61.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_44_sick_316_37.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_45_sick_318_73.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_46_sick_319_56.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_47_sick_320_27.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_48_sick_322_81.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_49_sick_326_67.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_4_sick_181_49.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_50_sick_328_67.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_51_sick_330_59.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_52_sick_337_43.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_53_sick_338_60.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_54_sick_342_50.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_55_sick_343_54.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_56_sick_344_56.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_57_sick_345_63.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_58_sick_346_31.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_59_sick_347_64.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_5_sick_192_54.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_60_sick_348_69.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_61_sick_350_24.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_62_sick_355_45.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_63_sick_356_70.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_64_sick_361_65.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_65_sick_363_42.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_66_sick_365_63.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_67_sick_366_90.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_68_sick_368_43.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_69_sick_369_56.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_6_sick_198_51.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_70_sick_371_60.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_71_sick_373_30.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_72_sick_374_58.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_73_sick_376_61.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_74_sick_378_59.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_75_sick_381_69.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_76_sick_384_33.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_77_sick_385_38.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_78_sick_386_43.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_79_sick_387_44.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_7_sick_202_57.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_80_sick_389_82.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_81_sick_390_51.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_82_sick_393_79.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_83_sick_394_85.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_84_sick_397_49.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_85_sick_398_00.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_86_sick_400_67.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_87_sick_401_81.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_88_sick_402_55.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_89_sick_407_52.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_8_sick_203_53.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_90_sick_408_51.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_91_sick_409_77.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_92_sick_410_52.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_93_sick_411_66.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_94_sick_412_66.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_95_sick_413_50.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_96_sick_415_53.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_97_sick_418_53.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_98_sick_422_43.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_99_sick_424_66.jpg
# ROI salvo em: D:/Unifesp/IA/termografia/termography/dataset/sick/roi\roi_9_sick_204_63.jpg
